# %% [markdown]
# #### Working With File Paths
# When working with files in Python, handling file paths correctly is crucial to ensure your code works across different operating systems and environments. Python provides several modules and functions for working with file paths effectively.

# %%
#### Using the os module
import os
cwd = os.getcwd()
print(f"Current working directory is {cwd}")
# Out:
# Current working directory is /home/hal/git/udemy/da_bootcamp_BtoA/python/5-Modules

# %%
## create a new directory
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created")
# Out:
# Directory 'package' created

# %%
## Listing Files And Directories
items = os.listdir('.') # '.' means current working directory
print(items)
# Out:
# ['5.1-import_modules_packages.ipynb', 'package', 'test.py', '5.2 standard_libraries.ipynb', 'source.txt', 'destination.txt', 'example.csv', '6.1 file_operations.ipynb', 'example.txt', 'example.bin', '6.2 working_filepath.ipynb', 'sample.txt']

# %%
### Joining Paths

dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(), dir_name, file_name)
print(full_path)
# Out:
# /home/hal/git/udemy/da_bootcamp_BtoA/python/5-Modules/folder/file.txt

# %%
file = 'example1.txt'
if os.path.exists(file):
    print(f"The path '{file}' exists")
else:
    print(f"The path '{file}' does not exists")
# Out:
# The path 'example1.txt' does not exists

# %%
#Checking if a Path is a File or Directory
import os

path = 'example1.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The path 'example1.txt' is neither a file nor a directory.

# %%
## Getting the absolute path (complete path)
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /home/hal/git/udemy/da_bootcamp_BtoA/python/5-Modules/example.txt
